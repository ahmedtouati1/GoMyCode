# %%
import pandas as pd
df = pd.read_csv('titanic-passengers.csv',sep=";")
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
def plot_correlation_map( df ):

    corr = df.corr()

    s , ax = plt.subplots( figsize =( 12 , 10 ) )

    cmap = sns.diverging_palette( 220 , 10 , as_cmap = True )

    s = sns.heatmap(

        corr, 

        cmap = cmap,

        square=True, 

        cbar_kws={ 'shrink' : .9 }, 

        ax=ax, 

        annot = True, 

        annot_kws = { 'fontsize' : 12 }

        )

# %%
plot_correlation_map( df )

# %%
df["Sex"]=df["Sex"].map({"male":1,"female":2})
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    1  28.0      0      0      248740  13.0000    NaN        S
# 1    1  25.0      0      0      348123   7.6500  F G73        S
# 2    1  20.0      0      0      350050   7.8542    NaN        S
# 3    2  29.0      0      4      349909  21.0750    NaN        S
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df["Survived"]=df["Survived"].map({"No":0,"Yes":1})
df.head()
# Out:
#    PassengerId  Survived  Pclass                                         Name  \
# 0          343         0       2                   Collander, Mr. Erik Gustaf
# 1           76         0       3                      Moen, Mr. Sigurd Hansen
# 2          641         0       3                       Jensen, Mr. Hans Peder
# 3          568         0       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672         0       1                       Davidson, Mr. Thornton
#
#    Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    1  28.0      0      0      248740  13.0000    NaN        S
# 1    1  25.0      0      0      348123   7.6500  F G73        S
# 2    1  20.0      0      0      350050   7.8542    NaN        S
# 3    2  29.0      0      4      349909  21.0750    NaN        S
# 4    1  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
df[['Pclass','Survived']].groupby ('Pclass').mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %%
df1= df.drop(columns=['Name','Ticket','Cabin'], axis=1)
df1.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0          343         0       2    1  28.0      0      0  13.0000        S
# 1           76         0       3    1  25.0      0      0   7.6500        S
# 2          641         0       3    1  20.0      0      0   7.8542        S
# 3          568         0       3    2  29.0      0      4  21.0750        S
# 4          672         0       1    1  31.0      1      0  52.0000        S

# %%
df1["Title"]=df["Name"]
print(df1)
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  \
# 0            343         0       2    1  28.0      0      0  13.0000        S
# 1             76         0       3    1  25.0      0      0   7.6500        S
# 2            641         0       3    1  20.0      0      0   7.8542        S
# 3            568         0       3    2  29.0      0      4  21.0750        S
# 4            672         0       1    1  31.0      1      0  52.0000        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886           10         1       2    2  14.0      1      0  30.0708        C
# 887           61         0       3    1  22.0      0      0   7.2292        C
# 888          535         0       3    2  30.0      0      0   8.6625        S
# 889          102         0       3    1   NaN      0      0   7.8958        S
# 890          428         1       2    2  19.0      0      0  26.0000        S
#
# ...

# %%
x=df1["Title"].str.split(pat=',').str.get(1).str.split(pat='.').str.get(0)
df1["x"]=x
print(df1["x"])
# Out:
# 0         Mr
# 1         Mr
# 2         Mr
# 3        Mrs
# 4         Mr
#        ...
# 886      Mrs
# 887       Mr
# 888     Miss
# 889       Mr
# 890     Miss
# Name: x, Length: 891, dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
grid=sns.FacetGrid(df1,col="Sex")
grid.map(sns.barplot,"Age","x" )
grid.add_legend()
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
Title_Dictionary = {

                    "Capt":       "Officer",

                    "Col":        "Officer",

                    "Major":      "Officer",

                      "Dr":         "Officer",

                    "Rev":        "Officer",

                    "Jonkheer":   "Royalty",

                    "Don":        "Royalty",

                    "Sir" :       "Royalty",

                   "Lady" :      "Royalty",

                  "the Countess": "Royalty",

                    "Dona":       "Royalty",

                    "Mme":        "Miss",

                    "Mlle":       "Miss",

                    "Miss" :      "Miss",

                    "Ms":         "Mrs",

                    "Mr" :        "Mrs",

                    "Mrs" :       "Mrs",

                    "Master" :    "Master"

                    }
df.replace(Title_Dictionary,inplace=True,regex=True)

# %%
df["FamilySize"]=df["Parch"]+df["SibSp"]
print(df["FamilySize"])
# Out:
# 0      0
# 1      0
# 2      0
# 3      4
# 4      1
#       ..
# 886    1
# 887    0
# 888    0
# 889    0
# 890    0
# Name: FamilySize, Length: 891, dtype: int64

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            343         0       2
# 1             76         0       3
# 2            641         0       3
# 3            568         0       3
# 4            672         0       1
# ..           ...       ...     ...
# 886           10         1       2
# 887           61         0       3
# 888          535         0       3
# 889          102         0       3
# 890          428         1       2
#
#                                                   Name  Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    1  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    1  25.0      0
# 2                               Jensen, Mr. Hans Peder    1  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)    2  29.0      0
# 4                               Davidson, Mr. Thornton    1  31.0      1
# ..                                                 ...  ...   ...    ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
grid=sns.FacetGrid(df,col="Survived")
grid.map(sns.barplot,"Pclass","FamilySize")
grid.add_legend()
# Out:
# /Users/macbook/opt/anaconda3/lib/python3.8/site-packages/seaborn/axisgrid.py:723: UserWarning: Using the barplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)
